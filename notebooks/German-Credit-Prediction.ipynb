# %% [markdown]
# # German Credit Prediction\n\nThis notebook documents a baseline workflow for predicting credit risk on the German Credit dataset.

# %% [markdown]
# ## Planned workflow\n1. Load and inspect the German Credit dataset\n2. Clean and encode features\n3. Train classification models\n4. Evaluate and compare model performance
